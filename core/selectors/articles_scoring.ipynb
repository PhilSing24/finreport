# %%
# Article Selector Scoring Analysis Notebook
# Shows internal scores for each article selected for NVDA (2025-10-01 to 2025-10-07)

import pandas as pd
from pathlib import Path
from dotenv import load_dotenv
import sys

# Add project root to path
sys.path.insert(0, str(Path.home() / "finreport"))

# Load environment
load_dotenv(Path.home() / "finreport" / ".env")

# Import the scoring functions directly
from core.selectors.select_finance_yahoo import (
    select_articles,
    calculate_article_score,
    _score_body_length,
    _score_content_relevance,
    FINANCIAL_KEYWORDS
)
from sqlalchemy import text
from core.data.db import engine

# === Parameters ===
TICKER = "TSLA"
START_DATE = "2025-10-01"
END_DATE = "2025-10-07"
MAX_ARTICLES = 3
MIN_BODY_CHARS = 800

print(f"Analyzing article scores for:")
print(f"  Ticker: {TICKER}")
print(f"  Period: {START_DATE} to {END_DATE}")
print(f"  Max articles: {MAX_ARTICLES}")
print(f"  Min body chars: {MIN_BODY_CHARS}")
print("\n" + "="*100 + "\n")

# === Query ALL articles (before selection) ===
query = text("""
    SELECT
        id, published_utc, published_date_utc,
        title, url, source,
        tickers, description, summary, tags, 
        full_body, full_body_chars
    FROM news_raw
    WHERE source = 'finance.yahoo.com'
      AND :ticker = ANY(tickers)
      AND published_date_utc >= CAST(:start AS date)
      AND published_date_utc < CAST(:end AS date)
      AND fetch_status = 'ok'
      AND full_body IS NOT NULL
      AND full_body_chars >= :min_chars
    ORDER BY published_utc
""")

params = {
    "ticker": TICKER.upper(),
    "start": START_DATE,
    "end": END_DATE,
    "min_chars": MIN_BODY_CHARS,
}

with engine.connect() as conn:
    df = pd.read_sql(query, conn, params=params)

print(f"Found {len(df)} total articles matching criteria\n")

if df.empty:
    print("⚠️  No articles found")
    sys.exit(0)

# === Calculate detailed scores for each article ===
scores_data = []

for idx, row in df.iterrows():
    article = row.to_dict()
    
    # Get individual score components
    body_length = article.get("full_body_chars") or 0
    title = article.get("title") or ""
    description = article.get("description") or ""
    summary = article.get("summary") or ""
    
    # Calculate component scores
    length_score = _score_body_length(body_length)
    content_score = _score_content_relevance(title, description, summary)
    total_score = calculate_article_score(article)
    
    # Count keyword matches
    title_lower = title.lower()
    desc_lower = description.lower()
    summ_lower = summary.lower()
    
    title_keywords = [kw for kw in FINANCIAL_KEYWORDS if kw in title_lower]
    desc_keywords = [kw for kw in FINANCIAL_KEYWORDS if kw in desc_lower]
    summ_keywords = [kw for kw in FINANCIAL_KEYWORDS if kw in summ_lower]
    
    scores_data.append({
        'id': article['id'],
        'published_utc': article['published_utc'],
        'title': title[:80] + '...' if len(title) > 80 else title,
        'body_chars': body_length,
        'length_score': round(length_score, 4),
        'content_score': round(content_score, 4),
        'total_score': round(total_score, 4),
        'title_kw_count': len(title_keywords),
        'desc_kw_count': len(set(desc_keywords)),
        'summ_kw_count': len(set(summ_keywords)),
        'title_keywords': ', '.join(title_keywords[:5]),
        'url': article['url']
    })

# Create DataFrame with scores
scores_df = pd.DataFrame(scores_data)
scores_df = scores_df.sort_values('total_score', ascending=False).reset_index(drop=True)

# === Display All Articles with Scores ===
print("\n" + "="*100)
print("📊 ALL ARTICLES RANKED BY SCORE")
print("="*100)
print("\nScore Calculation: 30% Length + 70% Content")
print("  - Length Score: Plateau curve favoring ~2500 chars")
print("  - Content Score: 40% title + 30% description + 30% summary keywords\n")

pd.set_option('display.max_rows', None)  # Show ALL rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 80)
pd.set_option('display.width', None)
pd.set_option('display.float_format', '{:.4f}'.format)

print(scores_df[['title', 'body_chars', 'length_score', 'content_score', 
                  'total_score', 'title_kw_count', 'desc_kw_count', 'summ_kw_count']].to_string(index=True))

# === Top Selected Articles ===
print("\n\n" + "="*100)
print(f"✅ TOP {MAX_ARTICLES} SELECTED ARTICLES (after MMR diversity)")
print("="*100)

selected_articles = select_articles(
    ticker=TICKER,
    start_date=START_DATE,
    end_date=END_DATE,
    max_articles=MAX_ARTICLES,
    min_body_chars=MIN_BODY_CHARS,
)

selected_ids = [a['id'] for a in selected_articles]
selected_df = scores_df[scores_df['id'].isin(selected_ids)]

print(selected_df[['title', 'body_chars', 'total_score', 
                    'title_kw_count', 'desc_kw_count']].to_string(index=False))

# === Detailed Breakdown ===
print("\n\n" + "="*100)
print("🔍 DETAILED SCORE BREAKDOWN FOR EACH ARTICLE")
print("="*100)

for idx, score_row in scores_df.iterrows():
    article_id = score_row['id']
    is_selected = article_id in selected_ids
    
    print(f"\n{'='*100}")
    print(f"ARTICLE #{idx + 1} {'✅ SELECTED' if is_selected else ''}")
    print('='*100)
    print(f"ID: {article_id}")
    print(f"Published: {score_row['published_utc']}")
    print(f"Title: {score_row['title']}")
    print(f"URL: {score_row['url']}")
    
    print(f"\n📏 BODY LENGTH")
    print(f"  Characters: {score_row['body_chars']:,}")
    print(f"  Length Score: {score_row['length_score']:.4f}")
    
    length_zone = ""
    chars = score_row['body_chars']
    if chars <= 500:
        length_zone = "Too short (<500)"
    elif chars <= 2500:
        length_zone = f"Rising (500-2500) → {score_row['length_score']:.2%}"
    elif chars == 2500:
        length_zone = "Peak (2500) → 100%"
    elif chars <= 6000:
        length_zone = f"Tapering (2500-6000) → {score_row['length_score']:.2%}"
    else:
        length_zone = "Too long (>6000) → capped at 80%"
    print(f"  Zone: {length_zone}")
    
    print(f"\n🎯 CONTENT RELEVANCE")
    print(f"  Content Score: {score_row['content_score']:.4f}")
    print(f"  Title keywords ({score_row['title_kw_count']}): {score_row['title_keywords']}")
    print(f"  Description keywords: {score_row['desc_kw_count']} unique")
    print(f"  Summary keywords: {score_row['summ_kw_count']} unique")
    
    # Calculate component contributions
    title_contrib = min(score_row['title_kw_count'] / 6.0, 1.0) * 0.4
    desc_contrib = min(score_row['desc_kw_count'] / 10.0, 1.0) * 0.3
    summ_contrib = min(score_row['summ_kw_count'] / 10.0, 1.0) * 0.3
    
    print(f"  ├─ Title contribution: {title_contrib:.4f} (40% weight)")
    print(f"  ├─ Description contribution: {desc_contrib:.4f} (30% weight)")
    print(f"  └─ Summary contribution: {summ_contrib:.4f} (30% weight)")
    
    print(f"\n🏆 FINAL SCORE")
    length_weighted = score_row['length_score'] * 0.30
    content_weighted = score_row['content_score'] * 0.70
    print(f"  Length (30%): {score_row['length_score']:.4f} × 0.30 = {length_weighted:.4f}")
    print(f"  Content (70%): {score_row['content_score']:.4f} × 0.70 = {content_weighted:.4f}")
    print(f"  TOTAL: {score_row['total_score']:.4f}")
    
    if is_selected:
        print(f"\n  ✅ Selected for final summary")

# === Statistics ===
print("\n\n" + "="*100)
print("📈 SCORING STATISTICS")
print("="*100)
print(f"\nTotal articles analyzed: {len(scores_df)}")
print(f"Articles selected: {len(selected_ids)}")
print(f"\nScore Distribution:")
print(f"  Mean total score: {scores_df['total_score'].mean():.4f}")
print(f"  Median total score: {scores_df['total_score'].median():.4f}")
print(f"  Min total score: {scores_df['total_score'].min():.4f}")
print(f"  Max total score: {scores_df['total_score'].max():.4f}")
print(f"  Std dev: {scores_df['total_score'].std():.4f}")

print(f"\nLength Scores:")
print(f"  Mean: {scores_df['length_score'].mean():.4f}")
print(f"  Median: {scores_df['length_score'].median():.4f}")

print(f"\nContent Scores:")
print(f"  Mean: {scores_df['content_score'].mean():.4f}")
print(f"  Median: {scores_df['content_score'].median():.4f}")

print(f"\nKeyword Matches:")
print(f"  Avg title keywords: {scores_df['title_kw_count'].mean():.1f}")
print(f"  Avg description keywords: {scores_df['desc_kw_count'].mean():.1f}")
print(f"  Avg summary keywords: {scores_df['summ_kw_count'].mean():.1f}")

# === Export ===
print("\n\n" + "="*100)
print("💾 EXPORT")
print("="*100)
output_path = Path.home() / "finreport" / "build" / f"article_scores_{TICKER}_{START_DATE}_{END_DATE}.csv"
scores_df.to_csv(output_path, index=False)
print(f"✅ Exported full scores to: {output_path}")

print("\n" + "="*100)
print("✅ Analysis complete!")
print("="*100)
selected_ids = [a['id'] for a in selected_articles]
selected_df = scores_df[scores_df['id'].isin(selected_ids)]

print(selected_df[['title', 'body_chars', 'total_score', 
                    'title_kw_count', 'desc_kw_count']].to_string(index=False))

# === Detailed Breakdown ===
print("\n\n" + "="*100)
print("🔍 DETAILED SCORE BREAKDOWN FOR EACH ARTICLE")
print("="*100)

for idx, score_row in scores_df.iterrows():
    article_id = score_row['id']
    is_selected = article_id in selected_ids
    
    print(f"\n{'='*100}")
    print(f"ARTICLE #{idx + 1} {'✅ SELECTED' if is_selected else ''}")
    print('='*100)
    print(f"ID: {article_id}")
    print(f"Published: {score_row['published_utc']}")
    print(f"Title: {score_row['title']}")
    print(f"URL: {score_row['url']}")
    
    print(f"\n📏 BODY LENGTH")
    print(f"  Characters: {score_row['body_chars']:,}")
    print(f"  Length Score: {score_row['length_score']:.4f}")
    
    length_zone = ""
    chars = score_row['body_chars']
    if chars <= 500:
        length_zone = "Too short (<500)"
    elif chars <= 2500:
        length_zone = f"Rising (500-2500) → {score_row['length_score']:.2%}"
    elif chars == 2500:
        length_zone = "Peak (2500) → 100%"
    elif chars <= 6000:
        length_zone = f"Tapering (2500-6000) → {score_row['length_score']:.2%}"
    else:
        length_zone = "Too long (>6000) → capped at 80%"
    print(f"  Zone: {length_zone}")
    
    print(f"\n🎯 CONTENT RELEVANCE")
    print(f"  Content Score: {score_row['content_score']:.4f}")
    print(f"  Title keywords ({score_row['title_kw_count']}): {score_row['title_keywords']}")
    print(f"  Description keywords: {score_row['desc_kw_count']} unique")
    print(f"  Summary keywords: {score_row['summ_kw_count']} unique")
    
    # Calculate component contributions
    title_contrib = min(score_row['title_kw_count'] / 6.0, 1.0) * 0.4
    desc_contrib = min(score_row['desc_kw_count'] / 10.0, 1.0) * 0.3
    summ_contrib = min(score_row['summ_kw_count'] / 10.0, 1.0) * 0.3
    
    print(f"  ├─ Title contribution: {title_contrib:.4f} (40% weight)")
    print(f"  ├─ Description contribution: {desc_contrib:.4f} (30% weight)")
    print(f"  └─ Summary contribution: {summ_contrib:.4f} (30% weight)")
    
    print(f"\n🏆 FINAL SCORE")
    length_weighted = score_row['length_score'] * 0.30
    content_weighted = score_row['content_score'] * 0.70
    print(f"  Length (30%): {score_row['length_score']:.4f} × 0.30 = {length_weighted:.4f}")
    print(f"  Content (70%): {score_row['content_score']:.4f} × 0.70 = {content_weighted:.4f}")
    print(f"  TOTAL: {score_row['total_score']:.4f}")
    
    if is_selected:
        print(f"\n  ✅ Selected for final summary")

# === Statistics ===
print("\n\n" + "="*100)
print("📈 SCORING STATISTICS")
print("="*100)
print(f"\nTotal articles analyzed: {len(scores_df)}")
print(f"Articles selected: {len(selected_ids)}")
print(f"\nScore Distribution:")
print(f"  Mean total score: {scores_df['total_score'].mean():.4f}")
print(f"  Median total score: {scores_df['total_score'].median():.4f}")
print(f"  Min total score: {scores_df['total_score'].min():.4f}")
print(f"  Max total score: {scores_df['total_score'].max():.4f}")
print(f"  Std dev: {scores_df['total_score'].std():.4f}")

print(f"\nLength Scores:")
print(f"  Mean: {scores_df['length_score'].mean():.4f}")
print(f"  Median: {scores_df['length_score'].median():.4f}")

print(f"\nContent Scores:")
print(f"  Mean: {scores_df['content_score'].mean():.4f}")
print(f"  Median: {scores_df['content_score'].median():.4f}")

print(f"\nKeyword Matches:")
print(f"  Avg title keywords: {scores_df['title_kw_count'].mean():.1f}")
print(f"  Avg description keywords: {scores_df['desc_kw_count'].mean():.1f}")
print(f"  Avg summary keywords: {scores_df['summ_kw_count'].mean():.1f}")

# === Export ===
print("\n\n" + "="*100)
print("💾 EXPORT")
print("="*100)
output_path = Path.home() / "finreport" / "build" / f"article_scores_{TICKER}_{START_DATE}_{END_DATE}.csv"
scores_df.to_csv(output_path, index=False)
print(f"✅ Exported full scores to: {output_path}")

print("\n" + "="*100)
print("✅ Analysis complete!")
print("="*100)
# Out:
# Analyzing article scores for:
#   Ticker: TSLA
#   Period: 2025-10-01 to 2025-10-07
#   Max articles: 3
#   Min body chars: 800
#
# ====================================================================================================
#
# Found 83 total articles matching criteria
#
#
# ====================================================================================================
# 📊 ALL ARTICLES RANKED BY SCORE
# ====================================================================================================
#
# Score Calculation: 30% Length + 70% Content
#   - Length Score: Plateau curve favoring ~2500 chars
#   - Content Score: 40% title + 30% description + 30% summary keywords
#
#                                                                                   title  body_chars  length_score  content_score  total_score  title_kw_count  desc_kw_count  summ_kw_count
# 0   Tesla (TSLA) Valuation: Examining Q3’s Record Deliveries and Policy-Driven Deman...        2891        0.9777         0.7400       0.8113               3              8             11
# 1                      Tesla sales rise 7% in Q3 as buyers rush to use $7,500 EV credit        2718        0.9875         0.6033       0.7186               5              5              4
# 2   Tesla Stock Slipped Despite Record Q3 Deliveries: Can The Company Make It Big Wi...        2594        0.9946         0.5233       0.6647               2              3             10
# 3                         Tesla Third Quarter 2025 Production, Deliveries & Deployments        2099        0.7995         0.5600       0.6319               3              2             10
# 4                               What You Need To Know Ahead of Tesla's Earnings Release        2440        0.9700         0.4867       0.6317               1              4             16
# 5   Analyst Explains Why He Downgraded Tesla (TSLA) to Sell Ahead of Upcoming Earnin...        3508        0.9424         0.4933       0.6281               2              2             16
# 6                             Tesla reports surprise increase in sales in third quarter        2830        0.9811         0.4700       0.6233               3              5              4
# 7                             Tesla reports surprise increase in sales in third quarter        2830        0.9811         0.4700       0.6233               3              5              4
# 8       Tesla Just Set a New Quarterly Delivery Record. Should You Buy TSLA Stock Here?        2437        0.9685         0.4700       0.6196               3              4              5
# 9                         Tesla tops Q3 delivery estimates with record 497,099 vehicles        2470        0.9850         0.4333       0.5988               2              5              5
# 10                             Tesla Deliveries Soar in Q3. But What Will Q4 Look Like?        2805        0.9826         0.4167       0.5864               4              1              4
# 11             Tesla's $1 Trillion AI Gamble Sends Stock Soaring--But Can Musk Deliver?        2193        0.8465         0.4633       0.5783               2              1             10
# 12        Assessing Tesla's Valuation After 22% Surge and Potential Trump Tariff Relief        2527        0.9985         0.3800       0.5655               3              2              4
# 13                     Analyst Explains Tesla’s (TSLA) ‘Big Question’ and New Struggles        3229        0.9583         0.3900       0.5605               0              3             15
# 14  As Elon Musk Hits $500B in Net Worth, Options Data Tells Us Tesla Stock Could Be...        2526        0.9985         0.3667       0.5562               1              5              5
# 15                Analyst Says He Doesn’t See ‘Any Upside’ For Tesla Stock – Here’s Why        3503        0.9427         0.3900       0.5558               0              3             17
# 16               Tesla Grabs One for the Road With Windfall from Expiring EV Tax Credit        2618        0.9933         0.3667       0.5546               1              2              8
# 17  Elon Musk Just Spent $1 Billion on Tesla Stock: Here’s What This Means for Inves...        2905        0.9769         0.3733       0.5544               2              2              6
# 18                       Tesla news: Q3 deliveries, Cybertruck lawsuit, Elon Musk's pay        2606        0.9939         0.3500       0.5432               3              0              5
# 19                          Elon Musk's fortune briefly jumped to a record $500 billion        2773        0.9844         0.3500       0.5403               3              3              2
# 20         Tesla Stock Is Down Today After Upbeat Deliveries News—And a Long Upward Run        2609        0.9938         0.3433       0.5385               2              0              7
# 21               Tesla Bounces Back From Its Sales Slump, But Can It Keep the Momentum?        2674        0.9901         0.3367       0.5327               1              3              6
# 22  Tesla smashes quarterly delivery numbers for the first time this year as EV cred...        2574        0.9958         0.3200       0.5227               3              3              1
# 23                         Tesla teases Tuesday event as focus shifts to affordable EVs        2407        0.9535         0.3300       0.5171               0              6              5
# 24                         Tesla teases Tuesday event as focus shifts to affordable EVs        2551        0.9971         0.3000       0.5091               0              7              3
# 25                 Tesla's monthly sales rise in France, Denmark for first time in 2025        2693        0.9890         0.2833       0.4950               2              3              2
# 26  Tesla under scrutiny after investigation reveals unusual bot scheme: 'The public...        2525        0.9986         0.2767       0.4932               1              0              7
# 27  Former Tesla exec claims EV industry will grow, not shrink, after death of $7,50...        2849        0.9801         0.2767       0.4877               1              2              5
# 28  Tesla Diner Served 50,000 Burgers Last Quarter, While The Company Saved 842 Mill...        2649        0.9915         0.2533       0.4748               2              2              2
# 29                          Tesla stock climbs on posts hinting possible new car launch        2796        0.9831         0.2467       0.4676               1              0              6
# 30  Elon Musk raises eyebrows with surprising $1 billion Tesla stock move: 'This sen...        2433        0.9665         0.2533       0.4673               2              0              4
# 31         Tesla teases fans with Tuesday event — here’s what investors are bracing for        2134        0.8170         0.3000       0.4551               0              4              6
# 32     Watch These Tesla Price Levels as Stock Shifts Gear After Soaring in 3rd Quarter        2725        0.9871         0.2233       0.4525               2              2              1
# 33  Elon Musk becomes world's first person to reach $500 billion net worth: '[It's] ...        2736        0.9865         0.2233       0.4523               2              0              3
# 34                 Tesla's tax credits are ending, but the AI benefit is only beginning        2512        0.9993         0.2100       0.4468               0              1              6
# 35                         Tesla teases Tuesday event as focus shifts to affordable EVs        2551        0.9971         0.2100       0.4461               0              4              3
# 36      William Blair: ’Increasingly difficult’ to like Tesla stock amid rich valuation        1956        0.7280         0.3067       0.4331               1              3              5
# 37  Tesla's former global sales chief says there are so many EV models now that the ...        2564        0.9963         0.1867       0.4296               1              1              3
# 38                                   Tesla posts record sales as US tax credits run out        2350        0.9250         0.2167       0.4292               1              3              2
# 39  Tesla and Uber announce game-changing partnership to launch new product: 'Earns ...        2842        0.9805         0.1867       0.4248               1              0              4
# 40      How Many Times Could You Fully Charge a Tesla for the Price of One Tesla Share?        2603        0.9941         0.1800       0.4242               0              2              4
# 41                 Tesla's monthly sales rise in France, Denmark for first time in 2025        1865        0.6825         0.3133       0.4241               2              3              3
# 42  If You Bought $1,000 of Tesla Stock Every Month Since 2020, Here’s How Much You’...        2731        0.9868         0.1567       0.4057               1              2              1
# 43         What's Tesla Teasing? The Stock Is Rising as Investors Look Ahead to Tuesday        2343        0.9215         0.1800       0.4024               0              0              6
# 44     Tesla's recent performance sparks debate among experts — here's what's happening        2723        0.9873         0.1500       0.4012               0              1              4
# 45  A group of Tesla investors is urging shareholders not to confirm Elon Musk's $1 ...        2510        0.9994         0.1267       0.3885               1              1              1
# 46  Elon Musk speaks out on controversial $1 trillion Tesla pay package: 'It's not a...        2533        0.9981         0.1267       0.3881               1              0              2
# 47                           Tesla teases Tuesday announcement with social media videos        2546        0.9974         0.1200       0.3832               0              0              4
# 48  Wall Street Is Bullish On Tesla Again, And It Has Nothing To Do With The Model Y...        2600        0.9943         0.1200       0.3823               0              1              3
# 49  Officials demand answers from Tesla as Elon Musk's statements don't match realit...        2683        0.9895         0.1200       0.3809               0              0              4
# 50               Tesla May Be Behind in Driverless Vehicles, but Here's a Silver Lining        2695        0.9889         0.1200       0.3807               0              1              3
# 51                         Tesla teases Tuesday event as focus shifts to affordable EVs        2291        0.8955         0.1500       0.3736               0              3              2
# 52                         Tesla teases Tuesday event as focus shifts to affordable EVs        1998        0.7490         0.2100       0.3717               0              5              2
# 53        Tesla Sales Are Finally Ticking Up in Europe. Should You Buy TSLA Stock Here?        7963        0.8000         0.1867       0.3707               1              1              3
# 54                                    Elon Musk's estimated net worth tops $500 billion        1636        0.5680         0.2833       0.3687               2              1              4
# 55  Parents Sue Tesla After Cybertruck Crash Kills Daughter, Allege Faulty Door Desi...        2503        0.9998         0.0900       0.3629               0              1              2
# 56                     Tesla Inc. (TSLA) Receives EV Sales Boost in Europe in September        1902        0.7010         0.2167       0.3620               1              2              3
# 57                                                   Why are buyers returning to Tesla?        2728        0.9870         0.0900       0.3591               0              2              1
# 58                                  The Fed Cut Rates — What This Means for Tesla Stock        2849        0.9801         0.0900       0.3570               0              0              3
# 59     Tesla fans are buzzing about a possible unveiling of a 'more affordable' vehicle        2314        0.9070         0.1200       0.3561               0              0              4
# 60                                  Tesla gets sales boost ahead of US EV incentive end        1435        0.4675         0.3067       0.3549               1              3              5
# 61  Tesla issues mandatory recall for product that can cause fires — here's what you...        2748        0.9858         0.0667       0.3424               1              0              0
# 62                    Unusual Tesla Call Options Volume Shows Investors Bullish on TSLA        2533        0.9981         0.0600       0.3414               0              0              2
# 63                                      Is Trending Stock Tesla, Inc. (TSLA) a Buy Now?        2565        0.9963         0.0600       0.3409               0              0              2
# 64                        Tesla sales rise in parts of Europe amid pressure from rivals        1020        0.2600         0.3733       0.3393               2              4              4
# 65       Tesla stock whipsaws after 3rd-quarter deliveries beat Wall Street's estimates        1668        0.5840         0.2300       0.3362               3              0              1
# 66                                            Tesla begins selling Cybertrucks in Qatar        1754        0.6270         0.2100       0.3351               0              3              4
# 67      Las Vegas Police Department Gets Customized Cybertrucks: 'It Will Stop Bullets'        2277        0.8885         0.0900       0.3296               0              1              2
# 68                                   Tesla posts record sales as US tax credits run out        1527        0.5135         0.2467       0.3267               1              3              3
# 69                                   Tesla sales up 7 percent ahead of tax credit’s end        1620        0.5600         0.2167       0.3197               1              3              2
# 70                                                     Where Will Tesla Be in 10 Years?        2633        0.9924         0.0300       0.3187               0              0              1
# 71            Tesla's Bulletproof Cybertruck Gets Rejected By Germany Over Basic Safety        2633        0.9924         0.0300       0.3187               0              0              1
# 72                                  Elon Musk becomes first person with $500B net worth        1190        0.3450         0.3067       0.3182               1              2              6
# 73                 Tesla and xAI Staff Are Fleeing as Musk Becomes Increasingly Erratic        2683        0.9895         0.0300       0.3179               0              0              1
# 74  Tesla hikes lease price for all US models as $7,500 EV tax credit expires, websi...        1561        0.5305         0.2167       0.3108               1              2              3
# 75               TSLA: Musk Sends Tesla Shares Soaring With Mysterious New Model Teaser        1198        0.3490         0.2467       0.2774               1              0              6
# 76                    Tesla UK sales flat in September despite broader EV market growth         831        0.1655         0.3133       0.2690               2              2              4
# 77                               Tesla delivers over 497,000 EVs in its Q3. Stock pops.        1135        0.3175         0.2467       0.2679               1              3              3
# 78  Elon Musk’s Tesla hikes lease prices on all electric cars as US tax credit expir...        1422        0.4610         0.1500       0.2433               0              2              3
# 79                   Tesla hikes lease prices as US electric vehicle tax credit expires        1561        0.5305         0.1200       0.2432               0              1              3
# 80                         Tesla teases Tuesday event as focus shifts to affordable EVs        1269        0.3845         0.1500       0.2203               0              4              1
# 81                             Tesla increases lease prices as US EV tax credit expires        1073        0.2865         0.0900       0.1489               0              1              2
# 82                                 Tesla teaser suggests new car could come out Tuesday        1074        0.2870         0.0000       0.0861               0              0              0
#
#
# ====================================================================================================
# ✅ TOP 3 SELECTED ARTICLES (after MMR diversity)
# ====================================================================================================
#                                                                               title  body_chars  total_score  title_kw_count  desc_kw_count
# Tesla (TSLA) Valuation: Examining Q3’s Record Deliveries and Policy-Driven Deman...        2891       0.8113               3              8
#                    Tesla sales rise 7% in Q3 as buyers rush to use $7,500 EV credit        2718       0.7186               5              5
#     Tesla Just Set a New Quarterly Delivery Record. Should You Buy TSLA Stock Here?        2437       0.6196               3              4
#
#
# ====================================================================================================
# 🔍 DETAILED SCORE BREAKDOWN FOR EACH ARTICLE
# ====================================================================================================
#
# ====================================================================================================
# ARTICLE #1 ✅ SELECTED
# ====================================================================================================
# ID: tiingo:88324574
# Published: 2025-10-03 13:30:07+00:00
# Title: Tesla (TSLA) Valuation: Examining Q3’s Record Deliveries and Policy-Driven Deman...
# URL: https://finance.yahoo.com/news/tesla-tsla-valuation-examining-q3-133007089.html
#
# 📏 BODY LENGTH
#   Characters: 2,891
#   Length Score: 0.9777
#   Zone: Tapering (2500-6000) → 97.77%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.7400
#   Title keywords (3): q3, valuation, deliveries
#   Description keywords: 8 unique
#   Summary keywords: 11 unique
#   ├─ Title contribution: 0.2000 (40% weight)
#   ├─ Description contribution: 0.2400 (30% weight)
#   └─ Summary contribution: 0.3000 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9777 × 0.30 = 0.2933
#   Content (70%): 0.7400 × 0.70 = 0.5180
#   TOTAL: 0.8113
#
#   ✅ Selected for final summary
#
# ====================================================================================================
# ARTICLE #2 ✅ SELECTED
# ====================================================================================================
# ID: tiingo:88296878
# Published: 2025-10-02 13:54:59+00:00
# Title: Tesla sales rise 7% in Q3 as buyers rush to use $7,500 EV credit
# URL: https://finance.yahoo.com/news/tesla-sales-rise-7-q3-135459402.html
#
# 📏 BODY LENGTH
#   Characters: 2,718
#   Length Score: 0.9875
#   Zone: Tapering (2500-6000) → 98.75%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.6033
#   Title keywords (5): q3, rise, sales, %, $
#   Description keywords: 5 unique
#   Summary keywords: 4 unique
#   ├─ Title contribution: 0.3333 (40% weight)
#   ├─ Description contribution: 0.1500 (30% weight)
#   └─ Summary contribution: 0.1200 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9875 × 0.30 = 0.2963
#   Content (70%): 0.6033 × 0.70 = 0.4223
#   TOTAL: 0.7186
#
#   ✅ Selected for final summary
#
# ====================================================================================================
# ARTICLE #3
# ====================================================================================================
# ID: tiingo:88335917
# Published: 2025-10-03 17:00:40+00:00
# Title: Tesla Stock Slipped Despite Record Q3 Deliveries: Can The Company Make It Big Wi...
# URL: https://finance.yahoo.com/news/tesla-stock-slipped-despite-record-170040181.html
#
# 📏 BODY LENGTH
#   Characters: 2,594
#   Length Score: 0.9946
#   Zone: Tapering (2500-6000) → 99.46%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.5233
#   Title keywords (2): q3, deliveries
#   Description keywords: 3 unique
#   Summary keywords: 10 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.3000 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9946 × 0.30 = 0.2984
#   Content (70%): 0.5233 × 0.70 = 0.3663
#   TOTAL: 0.6647
#
# ====================================================================================================
# ARTICLE #4
# ====================================================================================================
# ID: tiingo:88290449
# Published: 2025-10-02 13:04:00+00:00
# Title: Tesla Third Quarter 2025 Production, Deliveries & Deployments
# URL: https://finance.yahoo.com/news/tesla-third-quarter-2025-production-130400530.html
#
# 📏 BODY LENGTH
#   Characters: 2,099
#   Length Score: 0.7995
#   Zone: Rising (500-2500) → 79.95%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.5600
#   Title keywords (3): quarter, deliveries, production
#   Description keywords: 2 unique
#   Summary keywords: 10 unique
#   ├─ Title contribution: 0.2000 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.3000 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.7995 × 0.30 = 0.2398
#   Content (70%): 0.5600 × 0.70 = 0.3920
#   TOTAL: 0.6319
#
# ====================================================================================================
# ARTICLE #5
# ====================================================================================================
# ID: tiingo:88345185
# Published: 2025-10-04 04:39:25+00:00
# Title: What You Need To Know Ahead of Tesla's Earnings Release
# URL: https://finance.yahoo.com/news/know-ahead-teslas-earnings-release-043925025.html
#
# 📏 BODY LENGTH
#   Characters: 2,440
#   Length Score: 0.9700
#   Zone: Rising (500-2500) → 97.00%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.4867
#   Title keywords (1): earnings
#   Description keywords: 4 unique
#   Summary keywords: 16 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.1200 (30% weight)
#   └─ Summary contribution: 0.3000 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9700 × 0.30 = 0.2910
#   Content (70%): 0.4867 × 0.70 = 0.3407
#   TOTAL: 0.6317
#
# ====================================================================================================
# ARTICLE #6
# ====================================================================================================
# ID: tiingo:88270180
# Published: 2025-10-01 20:31:55+00:00
# Title: Analyst Explains Why He Downgraded Tesla (TSLA) to Sell Ahead of Upcoming Earnin...
# URL: https://finance.yahoo.com/news/analyst-explains-why-downgraded-tesla-203155089.html
#
# 📏 BODY LENGTH
#   Characters: 3,508
#   Length Score: 0.9424
#   Zone: Tapering (2500-6000) → 94.24%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.4933
#   Title keywords (2): earnings, downgrade
#   Description keywords: 2 unique
#   Summary keywords: 16 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.3000 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9424 × 0.30 = 0.2827
#   Content (70%): 0.4933 × 0.70 = 0.3453
#   TOTAL: 0.6281
#
# ====================================================================================================
# ARTICLE #7
# ====================================================================================================
# ID: tiingo:88291623
# Published: 2025-10-02 13:33:27+00:00
# Title: Tesla reports surprise increase in sales in third quarter
# URL: https://finance.yahoo.com/news/tesla-reports-surprise-increase-sales-133327405.html
#
# 📏 BODY LENGTH
#   Characters: 2,830
#   Length Score: 0.9811
#   Zone: Tapering (2500-6000) → 98.11%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.4700
#   Title keywords (3): quarter, rise, sales
#   Description keywords: 5 unique
#   Summary keywords: 4 unique
#   ├─ Title contribution: 0.2000 (40% weight)
#   ├─ Description contribution: 0.1500 (30% weight)
#   └─ Summary contribution: 0.1200 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9811 × 0.30 = 0.2943
#   Content (70%): 0.4700 × 0.70 = 0.3290
#   TOTAL: 0.6233
#
# ====================================================================================================
# ARTICLE #8
# ====================================================================================================
# ID: tiingo:88291626
# Published: 2025-10-02 13:33:27+00:00
# Title: Tesla reports surprise increase in sales in third quarter
# URL: https://finance.yahoo.com/news/tesla-reports-surprise-increase-sales-133327791.html
#
# 📏 BODY LENGTH
#   Characters: 2,830
#   Length Score: 0.9811
#   Zone: Tapering (2500-6000) → 98.11%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.4700
#   Title keywords (3): quarter, rise, sales
#   Description keywords: 5 unique
#   Summary keywords: 4 unique
#   ├─ Title contribution: 0.2000 (40% weight)
#   ├─ Description contribution: 0.1500 (30% weight)
#   └─ Summary contribution: 0.1200 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9811 × 0.30 = 0.2943
#   Content (70%): 0.4700 × 0.70 = 0.3290
#   TOTAL: 0.6233
#
# ====================================================================================================
# ARTICLE #9 ✅ SELECTED
# ====================================================================================================
# ID: tiingo:88303926
# Published: 2025-10-02 17:31:31+00:00
# Title: Tesla Just Set a New Quarterly Delivery Record. Should You Buy TSLA Stock Here?
# URL: https://finance.yahoo.com/news/tesla-just-set-quarterly-delivery-173131628.html
#
# 📏 BODY LENGTH
#   Characters: 2,437
#   Length Score: 0.9685
#   Zone: Rising (500-2500) → 96.85%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.4700
#   Title keywords (3): quarter, quarterly, delivery
#   Description keywords: 4 unique
#   Summary keywords: 5 unique
#   ├─ Title contribution: 0.2000 (40% weight)
#   ├─ Description contribution: 0.1200 (30% weight)
#   └─ Summary contribution: 0.1500 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9685 × 0.30 = 0.2905
#   Content (70%): 0.4700 × 0.70 = 0.3290
#   TOTAL: 0.6196
#
#   ✅ Selected for final summary
#
# ====================================================================================================
# ARTICLE #10
# ====================================================================================================
# ID: tiingo:88292254
# Published: 2025-10-02 13:40:10+00:00
# Title: Tesla tops Q3 delivery estimates with record 497,099 vehicles
# URL: https://finance.yahoo.com/news/tesla-tops-q3-delivery-estimates-134010555.html
#
# 📏 BODY LENGTH
#   Characters: 2,470
#   Length Score: 0.9850
#   Zone: Rising (500-2500) → 98.50%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.4333
#   Title keywords (2): q3, delivery
#   Description keywords: 5 unique
#   Summary keywords: 5 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.1500 (30% weight)
#   └─ Summary contribution: 0.1500 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9850 × 0.30 = 0.2955
#   Content (70%): 0.4333 × 0.70 = 0.3033
#   TOTAL: 0.5988
#
# ====================================================================================================
# ARTICLE #11
# ====================================================================================================
# ID: tiingo:88350608
# Published: 2025-10-04 14:05:00+00:00
# Title: Tesla Deliveries Soar in Q3. But What Will Q4 Look Like?
# URL: https://finance.yahoo.com/news/tesla-deliveries-soar-q3-q4-140500020.html
#
# 📏 BODY LENGTH
#   Characters: 2,805
#   Length Score: 0.9826
#   Zone: Tapering (2500-6000) → 98.26%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.4167
#   Title keywords (4): q3, q4, soar, deliveries
#   Description keywords: 1 unique
#   Summary keywords: 4 unique
#   ├─ Title contribution: 0.2667 (40% weight)
#   ├─ Description contribution: 0.0300 (30% weight)
#   └─ Summary contribution: 0.1200 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9826 × 0.30 = 0.2948
#   Content (70%): 0.4167 × 0.70 = 0.2917
#   TOTAL: 0.5864
#
# ====================================================================================================
# ARTICLE #12
# ====================================================================================================
# ID: tiingo:88256158
# Published: 2025-10-01 14:45:28+00:00
# Title: Tesla's $1 Trillion AI Gamble Sends Stock Soaring--But Can Musk Deliver?
# URL: https://finance.yahoo.com/news/teslas-1-trillion-ai-gamble-144528408.html
#
# 📏 BODY LENGTH
#   Characters: 2,193
#   Length Score: 0.8465
#   Zone: Rising (500-2500) → 84.65%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.4633
#   Title keywords (2): soar, $
#   Description keywords: 1 unique
#   Summary keywords: 10 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.0300 (30% weight)
#   └─ Summary contribution: 0.3000 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.8465 × 0.30 = 0.2540
#   Content (70%): 0.4633 × 0.70 = 0.3243
#   TOTAL: 0.5783
#
# ====================================================================================================
# ARTICLE #13
# ====================================================================================================
# ID: tiingo:88385299
# Published: 2025-10-06 12:04:00+00:00
# Title: Assessing Tesla's Valuation After 22% Surge and Potential Trump Tariff Relief
# URL: https://finance.yahoo.com/news/assessing-teslas-valuation-22-surge-120400654.html
#
# 📏 BODY LENGTH
#   Characters: 2,527
#   Length Score: 0.9985
#   Zone: Tapering (2500-6000) → 99.85%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3800
#   Title keywords (3): valuation, surge, %
#   Description keywords: 2 unique
#   Summary keywords: 4 unique
#   ├─ Title contribution: 0.2000 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.1200 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9985 × 0.30 = 0.2995
#   Content (70%): 0.3800 × 0.70 = 0.2660
#   TOTAL: 0.5655
#
# ====================================================================================================
# ARTICLE #14
# ====================================================================================================
# ID: tiingo:88324820
# Published: 2025-10-03 13:29:38+00:00
# Title: Analyst Explains Tesla’s (TSLA) ‘Big Question’ and New Struggles
# URL: https://finance.yahoo.com/news/analyst-explains-tesla-tsla-big-132938146.html
#
# 📏 BODY LENGTH
#   Characters: 3,229
#   Length Score: 0.9583
#   Zone: Tapering (2500-6000) → 95.83%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3900
#   Title keywords (0):
#   Description keywords: 3 unique
#   Summary keywords: 15 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.3000 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9583 × 0.30 = 0.2875
#   Content (70%): 0.3900 × 0.70 = 0.2730
#   TOTAL: 0.5605
#
# ====================================================================================================
# ARTICLE #15
# ====================================================================================================
# ID: tiingo:88334551
# Published: 2025-10-03 15:55:58+00:00
# Title: As Elon Musk Hits $500B in Net Worth, Options Data Tells Us Tesla Stock Could Be...
# URL: https://finance.yahoo.com/news/elon-musk-hits-500b-net-155558068.html
#
# 📏 BODY LENGTH
#   Characters: 2,526
#   Length Score: 0.9985
#   Zone: Tapering (2500-6000) → 99.85%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3667
#   Title keywords (1): $
#   Description keywords: 5 unique
#   Summary keywords: 5 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.1500 (30% weight)
#   └─ Summary contribution: 0.1500 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9985 × 0.30 = 0.2995
#   Content (70%): 0.3667 × 0.70 = 0.2567
#   TOTAL: 0.5562
#
# ====================================================================================================
# ARTICLE #16
# ====================================================================================================
# ID: tiingo:88325798
# Published: 2025-10-03 14:00:02+00:00
# Title: Analyst Says He Doesn’t See ‘Any Upside’ For Tesla Stock – Here’s Why
# URL: https://finance.yahoo.com/news/analyst-says-doesn-t-see-140002141.html
#
# 📏 BODY LENGTH
#   Characters: 3,503
#   Length Score: 0.9427
#   Zone: Tapering (2500-6000) → 94.27%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3900
#   Title keywords (0):
#   Description keywords: 3 unique
#   Summary keywords: 17 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.3000 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9427 × 0.30 = 0.2828
#   Content (70%): 0.3900 × 0.70 = 0.2730
#   TOTAL: 0.5558
#
# ====================================================================================================
# ARTICLE #17
# ====================================================================================================
# ID: tiingo:88331085
# Published: 2025-10-03 09:30:00+00:00
# Title: Tesla Grabs One for the Road With Windfall from Expiring EV Tax Credit
# URL: https://finance.yahoo.com/news/tesla-grabs-one-road-windfall-093000639.html
#
# 📏 BODY LENGTH
#   Characters: 2,618
#   Length Score: 0.9933
#   Zone: Tapering (2500-6000) → 99.33%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3667
#   Title keywords (1): fall
#   Description keywords: 2 unique
#   Summary keywords: 8 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.2400 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9933 × 0.30 = 0.2980
#   Content (70%): 0.3667 × 0.70 = 0.2567
#   TOTAL: 0.5546
#
# ====================================================================================================
# ARTICLE #18
# ====================================================================================================
# ID: tiingo:88364477
# Published: 2025-10-05 12:19:06+00:00
# Title: Elon Musk Just Spent $1 Billion on Tesla Stock: Here’s What This Means for Inves...
# URL: https://finance.yahoo.com/news/elon-musk-just-spent-1-121906900.html
#
# 📏 BODY LENGTH
#   Characters: 2,905
#   Length Score: 0.9769
#   Zone: Tapering (2500-6000) → 97.69%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3733
#   Title keywords (2): billion, $
#   Description keywords: 2 unique
#   Summary keywords: 6 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.1800 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9769 × 0.30 = 0.2931
#   Content (70%): 0.3733 × 0.70 = 0.2613
#   TOTAL: 0.5544
#
# ====================================================================================================
# ARTICLE #19
# ====================================================================================================
# ID: tiingo:88326984
# Published: 2025-10-03 14:25:01+00:00
# Title: Tesla news: Q3 deliveries, Cybertruck lawsuit, Elon Musk's pay
# URL: https://finance.yahoo.com/news/tesla-news-q3-deliveries-cybertruck-142501567.html
#
# 📏 BODY LENGTH
#   Characters: 2,606
#   Length Score: 0.9939
#   Zone: Tapering (2500-6000) → 99.39%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3500
#   Title keywords (3): q3, deliveries, lawsuit
#   Description keywords: 0 unique
#   Summary keywords: 5 unique
#   ├─ Title contribution: 0.2000 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.1500 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9939 × 0.30 = 0.2982
#   Content (70%): 0.3500 × 0.70 = 0.2450
#   TOTAL: 0.5432
#
# ====================================================================================================
# ARTICLE #20
# ====================================================================================================
# ID: tiingo:88287903
# Published: 2025-10-02 12:03:10+00:00
# Title: Elon Musk's fortune briefly jumped to a record $500 billion
# URL: https://finance.yahoo.com/news/elon-musks-fortune-briefly-jumped-120310951.html
#
# 📏 BODY LENGTH
#   Characters: 2,773
#   Length Score: 0.9844
#   Zone: Tapering (2500-6000) → 98.44%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3500
#   Title keywords (3): jump, billion, $
#   Description keywords: 3 unique
#   Summary keywords: 2 unique
#   ├─ Title contribution: 0.2000 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.0600 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9844 × 0.30 = 0.2953
#   Content (70%): 0.3500 × 0.70 = 0.2450
#   TOTAL: 0.5403
#
# ====================================================================================================
# ARTICLE #21
# ====================================================================================================
# ID: tiingo:88295707
# Published: 2025-10-02 15:40:18+00:00
# Title: Tesla Stock Is Down Today After Upbeat Deliveries News—And a Long Upward Run
# URL: https://finance.yahoo.com/news/tesla-stock-down-today-upbeat-154018030.html
#
# 📏 BODY LENGTH
#   Characters: 2,609
#   Length Score: 0.9938
#   Zone: Tapering (2500-6000) → 99.38%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3433
#   Title keywords (2): beat, deliveries
#   Description keywords: 0 unique
#   Summary keywords: 7 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.2100 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9938 × 0.30 = 0.2981
#   Content (70%): 0.3433 × 0.70 = 0.2403
#   TOTAL: 0.5385
#
# ====================================================================================================
# ARTICLE #22
# ====================================================================================================
# ID: tiingo:88353309
# Published: 2025-10-04 15:00:00+00:00
# Title: Tesla Bounces Back From Its Sales Slump, But Can It Keep the Momentum?
# URL: https://finance.yahoo.com/news/tesla-bounces-back-sales-slump-150000447.html
#
# 📏 BODY LENGTH
#   Characters: 2,674
#   Length Score: 0.9901
#   Zone: Tapering (2500-6000) → 99.01%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3367
#   Title keywords (1): sales
#   Description keywords: 3 unique
#   Summary keywords: 6 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.1800 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9901 × 0.30 = 0.2970
#   Content (70%): 0.3367 × 0.70 = 0.2357
#   TOTAL: 0.5327
#
# ====================================================================================================
# ARTICLE #23
# ====================================================================================================
# ID: tiingo:88291621
# Published: 2025-10-02 13:11:54+00:00
# Title: Tesla smashes quarterly delivery numbers for the first time this year as EV cred...
# URL: https://finance.yahoo.com/news/tesla-smashes-quarterly-delivery-numbers-131154840.html
#
# 📏 BODY LENGTH
#   Characters: 2,574
#   Length Score: 0.9958
#   Zone: Tapering (2500-6000) → 99.58%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3200
#   Title keywords (3): quarter, quarterly, delivery
#   Description keywords: 3 unique
#   Summary keywords: 1 unique
#   ├─ Title contribution: 0.2000 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.0300 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9958 × 0.30 = 0.2987
#   Content (70%): 0.3200 × 0.70 = 0.2240
#   TOTAL: 0.5227
#
# ====================================================================================================
# ARTICLE #24
# ====================================================================================================
# ID: tiingo:88393982
# Published: 2025-10-06 15:50:53+00:00
# Title: Tesla teases Tuesday event as focus shifts to affordable EVs
# URL: https://finance.yahoo.com/news/tesla-teases-tuesday-event-focus-155053476.html
#
# 📏 BODY LENGTH
#   Characters: 2,407
#   Length Score: 0.9535
#   Zone: Rising (500-2500) → 95.35%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3300
#   Title keywords (0):
#   Description keywords: 6 unique
#   Summary keywords: 5 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.1800 (30% weight)
#   └─ Summary contribution: 0.1500 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9535 × 0.30 = 0.2860
#   Content (70%): 0.3300 × 0.70 = 0.2310
#   TOTAL: 0.5171
#
# ====================================================================================================
# ARTICLE #25
# ====================================================================================================
# ID: tiingo:88401580
# Published: 2025-10-06 20:41:47+00:00
# Title: Tesla teases Tuesday event as focus shifts to affordable EVs
# URL: https://finance.yahoo.com/news/tesla-teases-tuesday-event-focus-204147238.html
#
# 📏 BODY LENGTH
#   Characters: 2,551
#   Length Score: 0.9971
#   Zone: Tapering (2500-6000) → 99.71%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3000
#   Title keywords (0):
#   Description keywords: 7 unique
#   Summary keywords: 3 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.2100 (30% weight)
#   └─ Summary contribution: 0.0900 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9971 × 0.30 = 0.2991
#   Content (70%): 0.3000 × 0.70 = 0.2100
#   TOTAL: 0.5091
#
# ====================================================================================================
# ARTICLE #26
# ====================================================================================================
# ID: tiingo:88238988
# Published: 2025-10-01 08:49:59+00:00
# Title: Tesla's monthly sales rise in France, Denmark for first time in 2025
# URL: https://finance.yahoo.com/news/teslas-monthly-sales-rise-france-084959810.html
#
# 📏 BODY LENGTH
#   Characters: 2,693
#   Length Score: 0.9890
#   Zone: Tapering (2500-6000) → 98.90%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2833
#   Title keywords (2): rise, sales
#   Description keywords: 3 unique
#   Summary keywords: 2 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.0600 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9890 × 0.30 = 0.2967
#   Content (70%): 0.2833 × 0.70 = 0.1983
#   TOTAL: 0.4950
#
# ====================================================================================================
# ARTICLE #27
# ====================================================================================================
# ID: tiingo:88308256
# Published: 2025-10-03 00:30:00+00:00
# Title: Tesla under scrutiny after investigation reveals unusual bot scheme: 'The public...
# URL: https://finance.yahoo.com/news/tesla-under-scrutiny-investigation-reveals-003000285.html
#
# 📏 BODY LENGTH
#   Characters: 2,525
#   Length Score: 0.9986
#   Zone: Tapering (2500-6000) → 99.86%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2767
#   Title keywords (1): investigation
#   Description keywords: 0 unique
#   Summary keywords: 7 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.2100 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9986 × 0.30 = 0.2996
#   Content (70%): 0.2767 × 0.70 = 0.1937
#   TOTAL: 0.4932
#
# ====================================================================================================
# ARTICLE #28
# ====================================================================================================
# ID: tiingo:88347128
# Published: 2025-10-04 08:02:00+00:00
# Title: Former Tesla exec claims EV industry will grow, not shrink, after death of $7,50...
# URL: https://finance.yahoo.com/news/former-tesla-exec-claims-ev-080200421.html
#
# 📏 BODY LENGTH
#   Characters: 2,849
#   Length Score: 0.9801
#   Zone: Tapering (2500-6000) → 98.01%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2767
#   Title keywords (1): $
#   Description keywords: 2 unique
#   Summary keywords: 5 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.1500 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9801 × 0.30 = 0.2940
#   Content (70%): 0.2767 × 0.70 = 0.1937
#   TOTAL: 0.4877
#
# ====================================================================================================
# ARTICLE #29
# ====================================================================================================
# ID: tiingo:88333947
# Published: 2025-10-03 18:31:03+00:00
# Title: Tesla Diner Served 50,000 Burgers Last Quarter, While The Company Saved 842 Mill...
# URL: https://finance.yahoo.com/news/tesla-diner-served-50-000-183103184.html
#
# 📏 BODY LENGTH
#   Characters: 2,649
#   Length Score: 0.9915
#   Zone: Tapering (2500-6000) → 99.15%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2533
#   Title keywords (2): quarter, million
#   Description keywords: 2 unique
#   Summary keywords: 2 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.0600 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9915 × 0.30 = 0.2974
#   Content (70%): 0.2533 × 0.70 = 0.1773
#   TOTAL: 0.4748
#
# ====================================================================================================
# ARTICLE #30
# ====================================================================================================
# ID: tiingo:88386835
# Published: 2025-10-06 12:40:58+00:00
# Title: Tesla stock climbs on posts hinting possible new car launch
# URL: https://finance.yahoo.com/news/tesla-stock-climbs-posts-hinting-124058435.html
#
# 📏 BODY LENGTH
#   Characters: 2,796
#   Length Score: 0.9831
#   Zone: Tapering (2500-6000) → 98.31%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2467
#   Title keywords (1): climb
#   Description keywords: 0 unique
#   Summary keywords: 6 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.1800 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9831 × 0.30 = 0.2949
#   Content (70%): 0.2467 × 0.70 = 0.1727
#   TOTAL: 0.4676
#
# ====================================================================================================
# ARTICLE #31
# ====================================================================================================
# ID: tiingo:88232903
# Published: 2025-10-01 01:00:00+00:00
# Title: Elon Musk raises eyebrows with surprising $1 billion Tesla stock move: 'This sen...
# URL: https://finance.yahoo.com/news/elon-musk-raises-eyebrows-surprising-010000501.html
#
# 📏 BODY LENGTH
#   Characters: 2,433
#   Length Score: 0.9665
#   Zone: Rising (500-2500) → 96.65%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2533
#   Title keywords (2): billion, $
#   Description keywords: 0 unique
#   Summary keywords: 4 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.1200 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9665 × 0.30 = 0.2899
#   Content (70%): 0.2533 × 0.70 = 0.1773
#   TOTAL: 0.4673
#
# ====================================================================================================
# ARTICLE #32
# ====================================================================================================
# ID: tiingo:88401593
# Published: 2025-10-06 16:39:22+00:00
# Title: Tesla teases fans with Tuesday event — here’s what investors are bracing for
# URL: https://finance.yahoo.com/news/tesla-teases-fans-tuesday-event-163922011.html
#
# 📏 BODY LENGTH
#   Characters: 2,134
#   Length Score: 0.8170
#   Zone: Rising (500-2500) → 81.70%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3000
#   Title keywords (0):
#   Description keywords: 4 unique
#   Summary keywords: 6 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.1200 (30% weight)
#   └─ Summary contribution: 0.1800 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.8170 × 0.30 = 0.2451
#   Content (70%): 0.3000 × 0.70 = 0.2100
#   TOTAL: 0.4551
#
# ====================================================================================================
# ARTICLE #33
# ====================================================================================================
# ID: tiingo:88329231
# Published: 2025-10-03 15:40:20+00:00
# Title: Watch These Tesla Price Levels as Stock Shifts Gear After Soaring in 3rd Quarter
# URL: https://finance.yahoo.com/news/watch-tesla-price-levels-stock-154020982.html
#
# 📏 BODY LENGTH
#   Characters: 2,725
#   Length Score: 0.9871
#   Zone: Tapering (2500-6000) → 98.71%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2233
#   Title keywords (2): quarter, soar
#   Description keywords: 2 unique
#   Summary keywords: 1 unique
# ...
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2100
#   Title keywords (0):
#   Description keywords: 3 unique
#   Summary keywords: 4 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.1200 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.6270 × 0.30 = 0.1881
#   Content (70%): 0.2100 × 0.70 = 0.1470
#   TOTAL: 0.3351
#
# ====================================================================================================
# ARTICLE #68
# ====================================================================================================
# ID: tiingo:88303932
# Published: 2025-10-02 20:31:04+00:00
# Title: Las Vegas Police Department Gets Customized Cybertrucks: 'It Will Stop Bullets'
# URL: https://finance.yahoo.com/news/las-vegas-police-department-gets-203104802.html
#
# 📏 BODY LENGTH
#   Characters: 2,277
#   Length Score: 0.8885
#   Zone: Rising (500-2500) → 88.85%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.0900
#   Title keywords (0):
#   Description keywords: 1 unique
#   Summary keywords: 2 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0300 (30% weight)
#   └─ Summary contribution: 0.0600 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.8885 × 0.30 = 0.2665
#   Content (70%): 0.0900 × 0.70 = 0.0630
#   TOTAL: 0.3296
#
# ====================================================================================================
# ARTICLE #69
# ====================================================================================================
# ID: tiingo:88295318
# Published: 2025-10-02 15:18:26+00:00
# Title: Tesla posts record sales as US tax credits run out
# URL: https://finance.yahoo.com/news/tesla-posts-record-sales-us-151826505.html
#
# 📏 BODY LENGTH
#   Characters: 1,527
#   Length Score: 0.5135
#   Zone: Rising (500-2500) → 51.35%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2467
#   Title keywords (1): sales
#   Description keywords: 3 unique
#   Summary keywords: 3 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.0900 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.5135 × 0.30 = 0.1540
#   Content (70%): 0.2467 × 0.70 = 0.1727
#   TOTAL: 0.3267
#
# ====================================================================================================
# ARTICLE #70
# ====================================================================================================
# ID: tiingo:88306123
# Published: 2025-10-02 19:52:29+00:00
# Title: Tesla sales up 7 percent ahead of tax credit’s end
# URL: https://finance.yahoo.com/news/tesla-sales-7-percent-ahead-195229578.html
#
# 📏 BODY LENGTH
#   Characters: 1,620
#   Length Score: 0.5600
#   Zone: Rising (500-2500) → 56.00%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2167
#   Title keywords (1): sales
#   Description keywords: 3 unique
#   Summary keywords: 2 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.0600 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.5600 × 0.30 = 0.1680
#   Content (70%): 0.2167 × 0.70 = 0.1517
#   TOTAL: 0.3197
#
# ====================================================================================================
# ARTICLE #71
# ====================================================================================================
# ID: tiingo:88362119
# Published: 2025-10-05 08:50:00+00:00
# Title: Where Will Tesla Be in 10 Years?
# URL: https://finance.yahoo.com/news/where-tesla-10-years-085000729.html
#
# 📏 BODY LENGTH
#   Characters: 2,633
#   Length Score: 0.9924
#   Zone: Tapering (2500-6000) → 99.24%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.0300
#   Title keywords (0):
#   Description keywords: 0 unique
#   Summary keywords: 1 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.0300 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9924 × 0.30 = 0.2977
#   Content (70%): 0.0300 × 0.70 = 0.0210
#   TOTAL: 0.3187
#
# ====================================================================================================
# ARTICLE #72
# ====================================================================================================
# ID: tiingo:88370083
# Published: 2025-10-05 16:30:00+00:00
# Title: Tesla's Bulletproof Cybertruck Gets Rejected By Germany Over Basic Safety
# URL: https://finance.yahoo.com/news/teslas-bulletproof-cybertruck-gets-rejected-163000341.html
#
# 📏 BODY LENGTH
#   Characters: 2,633
#   Length Score: 0.9924
#   Zone: Tapering (2500-6000) → 99.24%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.0300
#   Title keywords (0):
#   Description keywords: 0 unique
#   Summary keywords: 1 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.0300 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9924 × 0.30 = 0.2977
#   Content (70%): 0.0300 × 0.70 = 0.0210
#   TOTAL: 0.3187
#
# ====================================================================================================
# ARTICLE #73
# ====================================================================================================
# ID: tiingo:88290901
# Published: 2025-10-02 13:20:34+00:00
# Title: Elon Musk becomes first person with $500B net worth
# URL: https://finance.yahoo.com/news/elon-musk-becomes-first-person-132034427.html
#
# 📏 BODY LENGTH
#   Characters: 1,190
#   Length Score: 0.3450
#   Zone: Rising (500-2500) → 34.50%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3067
#   Title keywords (1): $
#   Description keywords: 2 unique
#   Summary keywords: 6 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.1800 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.3450 × 0.30 = 0.1035
#   Content (70%): 0.3067 × 0.70 = 0.2147
#   TOTAL: 0.3182
#
# ====================================================================================================
# ARTICLE #74
# ====================================================================================================
# ID: tiingo:88354404
# Published: 2025-10-04 19:00:00+00:00
# Title: Tesla and xAI Staff Are Fleeing as Musk Becomes Increasingly Erratic
# URL: https://finance.yahoo.com/news/tesla-xai-staff-fleeing-musk-190000454.html
#
# 📏 BODY LENGTH
#   Characters: 2,683
#   Length Score: 0.9895
#   Zone: Tapering (2500-6000) → 98.95%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.0300
#   Title keywords (0):
#   Description keywords: 0 unique
#   Summary keywords: 1 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.0300 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.9895 × 0.30 = 0.2969
#   Content (70%): 0.0300 × 0.70 = 0.0210
#   TOTAL: 0.3179
#
# ====================================================================================================
# ARTICLE #75
# ====================================================================================================
# ID: tiingo:88237592
# Published: 2025-10-01 07:34:40+00:00
# Title: Tesla hikes lease price for all US models as $7,500 EV tax credit expires, websi...
# URL: https://finance.yahoo.com/news/tesla-hikes-lease-price-us-073440875.html
#
# 📏 BODY LENGTH
#   Characters: 1,561
#   Length Score: 0.5305
#   Zone: Rising (500-2500) → 53.05%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2167
#   Title keywords (1): $
#   Description keywords: 2 unique
#   Summary keywords: 3 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.0900 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.5305 × 0.30 = 0.1591
#   Content (70%): 0.2167 × 0.70 = 0.1517
#   TOTAL: 0.3108
#
# ====================================================================================================
# ARTICLE #76
# ====================================================================================================
# ID: tiingo:88399033
# Published: 2025-10-06 19:03:21+00:00
# Title: TSLA: Musk Sends Tesla Shares Soaring With Mysterious New Model Teaser
# URL: https://finance.yahoo.com/news/tsla-musk-sends-tesla-shares-190321560.html
#
# 📏 BODY LENGTH
#   Characters: 1,198
#   Length Score: 0.3490
#   Zone: Rising (500-2500) → 34.90%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2467
#   Title keywords (1): soar
#   Description keywords: 0 unique
#   Summary keywords: 6 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.1800 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.3490 × 0.30 = 0.1047
#   Content (70%): 0.2467 × 0.70 = 0.1727
#   TOTAL: 0.2774
#
# ====================================================================================================
# ARTICLE #77
# ====================================================================================================
# ID: tiingo:88321726
# Published: 2025-10-03 12:20:06+00:00
# Title: Tesla UK sales flat in September despite broader EV market growth
# URL: https://finance.yahoo.com/news/tesla-uk-sales-flat-september-122006391.html
#
# 📏 BODY LENGTH
#   Characters: 831
#   Length Score: 0.1655
#   Zone: Rising (500-2500) → 16.55%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.3133
#   Title keywords (2): sales, growth
#   Description keywords: 2 unique
#   Summary keywords: 4 unique
#   ├─ Title contribution: 0.1333 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.1200 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.1655 × 0.30 = 0.0496
#   Content (70%): 0.3133 × 0.70 = 0.2193
#   TOTAL: 0.2690
#
# ====================================================================================================
# ARTICLE #78
# ====================================================================================================
# ID: tiingo:88291628
# Published: 2025-10-02 13:23:30+00:00
# Title: Tesla delivers over 497,000 EVs in its Q3. Stock pops.
# URL: https://finance.yahoo.com/video/tesla-delivers-over-497-000-132330690.html
#
# 📏 BODY LENGTH
#   Characters: 1,135
#   Length Score: 0.3175
#   Zone: Rising (500-2500) → 31.75%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.2467
#   Title keywords (1): q3
#   Description keywords: 3 unique
#   Summary keywords: 3 unique
#   ├─ Title contribution: 0.0667 (40% weight)
#   ├─ Description contribution: 0.0900 (30% weight)
#   └─ Summary contribution: 0.0900 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.3175 × 0.30 = 0.0953
#   Content (70%): 0.2467 × 0.70 = 0.1727
#   TOTAL: 0.2679
#
# ====================================================================================================
# ARTICLE #79
# ====================================================================================================
# ID: tiingo:88272082
# Published: 2025-10-01 17:20:21+00:00
# Title: Elon Musk’s Tesla hikes lease prices on all electric cars as US tax credit expir...
# URL: https://finance.yahoo.com/news/elon-musk-tesla-hikes-lease-172021321.html
#
# 📏 BODY LENGTH
#   Characters: 1,422
#   Length Score: 0.4610
#   Zone: Rising (500-2500) → 46.10%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.1500
#   Title keywords (0):
#   Description keywords: 2 unique
#   Summary keywords: 3 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0600 (30% weight)
#   └─ Summary contribution: 0.0900 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.4610 × 0.30 = 0.1383
#   Content (70%): 0.1500 × 0.70 = 0.1050
#   TOTAL: 0.2433
#
# ====================================================================================================
# ARTICLE #80
# ====================================================================================================
# ID: tiingo:88259256
# Published: 2025-10-01 16:00:25+00:00
# Title: Tesla hikes lease prices as US electric vehicle tax credit expires
# URL: https://finance.yahoo.com/news/tesla-hikes-lease-prices-us-160025319.html
#
# 📏 BODY LENGTH
#   Characters: 1,561
#   Length Score: 0.5305
#   Zone: Rising (500-2500) → 53.05%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.1200
#   Title keywords (0):
#   Description keywords: 1 unique
#   Summary keywords: 3 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0300 (30% weight)
#   └─ Summary contribution: 0.0900 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.5305 × 0.30 = 0.1591
#   Content (70%): 0.1200 × 0.70 = 0.0840
#   TOTAL: 0.2432
#
# ====================================================================================================
# ARTICLE #81
# ====================================================================================================
# ID: tiingo:88375436
# Published: 2025-10-06 04:35:56+00:00
# Title: Tesla teases Tuesday event as focus shifts to affordable EVs
# URL: https://finance.yahoo.com/news/tesla-teases-tuesday-event-focus-043556738.html
#
# 📏 BODY LENGTH
#   Characters: 1,269
#   Length Score: 0.3845
#   Zone: Rising (500-2500) → 38.45%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.1500
#   Title keywords (0):
#   Description keywords: 4 unique
#   Summary keywords: 1 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.1200 (30% weight)
#   └─ Summary contribution: 0.0300 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.3845 × 0.30 = 0.1153
#   Content (70%): 0.1500 × 0.70 = 0.1050
#   TOTAL: 0.2203
#
# ====================================================================================================
# ARTICLE #82
# ====================================================================================================
# ID: tiingo:88237927
# Published: 2025-10-01 08:02:44+00:00
# Title: Tesla increases lease prices as US EV tax credit expires
# URL: https://finance.yahoo.com/news/tesla-increases-lease-prices-us-080244163.html
#
# 📏 BODY LENGTH
#   Characters: 1,073
#   Length Score: 0.2865
#   Zone: Rising (500-2500) → 28.65%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.0900
#   Title keywords (0):
#   Description keywords: 1 unique
#   Summary keywords: 2 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0300 (30% weight)
#   └─ Summary contribution: 0.0600 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.2865 × 0.30 = 0.0859
#   Content (70%): 0.0900 × 0.70 = 0.0630
#   TOTAL: 0.1489
#
# ====================================================================================================
# ARTICLE #83
# ====================================================================================================
# ID: tiingo:88399656
# Published: 2025-10-06 19:41:23+00:00
# Title: Tesla teaser suggests new car could come out Tuesday
# URL: https://finance.yahoo.com/news/tesla-teaser-suggests-car-could-194123968.html
#
# 📏 BODY LENGTH
#   Characters: 1,074
#   Length Score: 0.2870
#   Zone: Rising (500-2500) → 28.70%
#
# 🎯 CONTENT RELEVANCE
#   Content Score: 0.0000
#   Title keywords (0):
#   Description keywords: 0 unique
#   Summary keywords: 0 unique
#   ├─ Title contribution: 0.0000 (40% weight)
#   ├─ Description contribution: 0.0000 (30% weight)
#   └─ Summary contribution: 0.0000 (30% weight)
#
# 🏆 FINAL SCORE
#   Length (30%): 0.2870 × 0.30 = 0.0861
#   Content (70%): 0.0000 × 0.70 = 0.0000
#   TOTAL: 0.0861
#
#
# ====================================================================================================
# 📈 SCORING STATISTICS
# ====================================================================================================
#
# Total articles analyzed: 83
# Articles selected: 3
#
# Score Distribution:
#   Mean total score: 0.4334
#   Median total score: 0.4241
#   Min total score: 0.0861
#   Max total score: 0.8113
#   Std dev: 0.1292
#
# Length Scores:
#   Mean: 0.8453
#   Median: 0.9805
#
# Content Scores:
#   Mean: 0.2569
#   Median: 0.2467
#
# Keyword Matches:
#   Avg title keywords: 1.1
#   Avg description keywords: 2.0
#   Avg summary keywords: 4.3
#
#
# ====================================================================================================
# 💾 EXPORT
# ====================================================================================================
# ✅ Exported full scores to: /home/philippe/finreport/build/article_scores_TSLA_2025-10-01_2025-10-07.csv
#
# ====================================================================================================
# ✅ Analysis complete!
# ====================================================================================================
